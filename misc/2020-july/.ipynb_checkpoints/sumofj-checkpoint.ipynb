# %%
import numpy as np, scipy as sp
import time
from matplotlib import pyplot as p
from importlib import reload

# %% [markdown]
# Let $J$ be the random variable with $\mathbb P(J = j) = 1/j(j+1)$.
#
# If we currently have $x$ active sites, then one step works like this:
# * the rightmost active chip falls asleep with probability $q$.
# * it moves left with probability $(1-q)/2$, and then randomly walks until it returns to the origin. This will wake up $J$ sites to the left of the chip, but $x - 1$ were already awake anyway, so the new number of awake sites is $(J+1) \vee x$.
# * it moves right with probability $(1-q)/2$, and then randomly walks until it returns to the origin. This wakes up $J$ sites to the left of the chip which were asleep at first, so the number of awake sites is $J + x$.

# %% [markdown]
# ### the behaviour of sums of many J

# %% [markdown]
# The characteristic function of $J$ is $$F(\theta) := \mathbb E[e^{i\theta J}] = (e^{-i\theta} - 1) \log(1 - e^{i\theta}) + 1,$$ where we are using the principal branch.
#
# Let $S_N$ be the sum of $N$ independent copies of $J$. Its characteristic function is
# $F(\theta)^N = [1 + (e^{-i\theta} - 1) \log(1 - e^{i\theta})]^N$.
#
# Here $e^{-i\theta} - 1 = -i\theta (1 + O(\theta))$ and $\log(1 - e^{i\theta}) = \log(-i\theta) (1 + O(\theta))$, so
#
# $$F(\theta)^N = \exp(-i \theta N \log(-i \theta) (1 + O(\theta))).$$
#
# This is a nice formula. From this, we can easily get
#
# $${S_N - N \log N \over N} \stackrel{d}{\to} \mathfrak J$$
#
# where $\mathfrak J$ is a random variable with characteristic function $e^{-i\theta \log -i\theta} = e^{-\pi |\theta| / 2 - i \theta \log |\theta|}$.
# We can get rigorous approximations of things like $\mathbb P(\mathfrak{J} < x)$ by using the formula
# $$\mathbb P(X < x) = \frac12 - \frac{1}{2\pi{i}} \lim_{B \to \infty} \int_{-B}^{B} \left({e^{-ix\theta} \mathbb E[e^{iX\theta}] - 1 \over \theta}\right) \,d\theta$$
# <!--$$\mathbb P(X < x) = \frac12 - \frac{1}{2\pi} \int_{-\infty}^{\infty} \mathop{\text{Im}} {e^{-ix\theta} \mathbb E[e^{iX\theta}] \over \theta} \,d\theta.$$-->
#
# It would be nice to evaluate this integral with rigorous bounds. We can truncate it at e.g. $B = 100$ with very little error because $|\mathbb E[e^{iX\theta}]| = e^{-\pi |\theta| / 2}$ and $1/\theta$ cancels out on $[-B,-1] \cup [1,B]$. There is only a logarithmic singularity at zero, so the numerical integration routines in numpy work okay, but of course the bounds aren't rigorous. Anyway, it's plotted and compared to empirical estimate.

# %%
# we can get samples of j by floor(1/U) where U is uniform on (0, 1]
# floating point isn't perfect but it's close
def generateJ(shape):
    return np.floor(1/np.random.random(shape)).astype(int)
def generate_sum_of_j(count):
    return np.sum(generateJ(count))

# %%
many = 1000000

def sample(many):
    samples = []
    count = 100000
    t = time.time()
    print("Generating %d samples of sums of %d independent copies of J" % (count, many))
    for j in range(count):
        samples.append((generate_sum_of_j(many) - many * np.log(many)) / many)
        if time.time() > t + 1:
            print("%d generated" % j)
            t += 1
    return samples

# cumulative distribution function
def cdf(samples):
    x = np.sort(samples)
    y = np.arange(len(samples)) / len(samples)
    #pass
    #x = np.concatenate([[0], x])
    #y = np.concatenate([[0], y])
    p.plot(x, y)

# %% [markdown]
# #### Generate the samples

# %%
samples_for_n = {}
for many in [10, 100, 1000, 10000, 100000, 1000000]:
    samples_for_n[many] = sample(many)
# Out:
# Generating 100000 samples of sums of 10 independent copies of J
# 75895 generated
# Generating 100000 samples of sums of 100 independent copies of J
# 75273 generated
# Generating 100000 samples of sums of 1000 independent copies of J
# 49840 generated
# 99582 generated
# Generating 100000 samples of sums of 10000 independent copies of J
# 11746 generated
# 23477 generated
# 35210 generated
# 46938 generated
# 58675 generated
# 70422 generated
# 82166 generated
# 93895 generated
# Generating 100000 samples of sums of 100000 independent copies of J
# 1377 generated
# 2744 generated
# 4120 generated
# 5498 generated
# 6876 generated
# 8253 generated
# 9631 generated
# 11010 generated
# 12387 generated
# 13766 generated
# 15144 generated
# 16522 generated
# 17899 generated
# 19278 generated
# 20655 generated
# 22033 generated
# 23410 generated
# 24787 generated
# 26164 generated
# 27542 generated
# 28920 generated
# 30298 generated
# 31676 generated
# 33052 generated
# 34428 generated
# 35806 generated
# 37183 generated
# 38559 generated
# 39936 generated
# 41312 generated
# 42688 generated
# 44064 generated
# 45441 generated
# 46817 generated
# 48194 generated
# 49571 generated
# 50947 generated
# 52324 generated
# 53700 generated
# 55076 generated
# 56453 generated
# 57830 generated
# 59206 generated
# 60584 generated
# 61962 generated
# 63339 generated
# 64716 generated
# 66094 generated
# 67471 generated
# 68850 generated
# 70226 generated
# 71604 generated
# 72981 generated
# 74358 generated
# 75734 generated
# 77112 generated
# 78490 generated
# 79868 generated
# 81245 generated
# 82622 generated
# 83999 generated
# 85376 generated
# 86753 generated
# 88130 generated
# 89506 generated
# 90884 generated
# 92261 generated
# 93636 generated
# 95012 generated
# 96389 generated
# 97765 generated
# 99141 generated
# Generating 100000 samples of sums of 1000000 independent copies of J
# 119 generated
# 239 generated
# 359 generated
# 479 generated
# 599 generated
# 718 generated
# 838 generated
# 958 generated
# 1077 generated
# 1197 generated
# 1317 generated
# 1437 generated
# 1557 generated
# 1677 generated
# 1796 generated
# 1916 generated
# 2036 generated
# 2156 generated
# 2276 generated
# 2396 generated
# 2516 generated
# 2636 generated
# 2756 generated
# 2876 generated
# 2996 generated
# 3116 generated
# 3236 generated
# 3356 generated
# 3476 generated
# 3596 generated
# 3716 generated
# 3836 generated
# 3956 generated
# 4076 generated
# 4196 generated
# 4316 generated
# 4436 generated
# 4556 generated
# 4675 generated
# 4795 generated
# 4915 generated
# 5035 generated
# 5155 generated
# 5275 generated
# 5395 generated
# 5515 generated
# 5635 generated
# 5755 generated
# 5875 generated
# 5995 generated
# 6114 generated
# 6234 generated
# 93073 generated
# 93193 generated
# 93313 generated
# 93433 generated
# 93552 generated
# 93672 generated
# 93792 generated
# 93912 generated
# 94032 generated
# 94152 generated
# 94272 generated
# 94392 generated
# 94512 generated
# 94632 generated
# 94752 generated
# 94872 generated
# 94992 generated
# 95111 generated
# 95231 generated
# 95351 generated
# 95471 generated
# 95591 generated
# 95711 generated
# 95831 generated
# 95951 generated
# 96071 generated
# 96191 generated
# 96311 generated
# 96431 generated
# 96551 generated
# 96671 generated
# 96791 generated
# 96911 generated
# 97031 generated
# 97151 generated
# 97271 generated
# 97391 generated
# 97510 generated
# 97630 generated
# 97750 generated
# 97870 generated
# 97989 generated
# 98109 generated
# 98229 generated
# 98349 generated
# 98468 generated
# 98588 generated
# 98708 generated
# 98828 generated
# 98948 generated
# 99068 generated
# 99187 generated
# 99307 generated
# 99427 generated
# 99547 generated
# 99667 generated
# 99787 generated
# 99907 generated

# %% [markdown]
# #### Plot the samples

# %%
p.figure(figsize=(16, 6))
cdf(samples)
p.xlabel("$(S_N - N\,\log\,N) / N$")
p.ylabel("cumulative probability")
p.xlim([-20, 20])
p.show()

# %% [markdown]
# #### cdf of $\mathfrak{J}$

# %%
import scipy.integrate

# %% [markdown]
# We compute the integral
# $$\mathbb P(\mathfrak{J} < x) \approx {1 \over 2} - {1 \over 2 \pi i} \int_{-100}^{100} {e^{-\pi|\theta|/ 2 - i\theta \log |\theta| - ix\theta} - 1 \over \theta} \,d\theta.$$
# or
# $$\int_{-100}^{100} {\sin(\theta \log |\theta| - x\theta) e^{-\pi|\theta| / 2} \over \theta} \,d\theta$$
#
# Uh, if we make the change of variables $\theta = e^y$, then the positive integral would become
# $$\int_{-\infty}^{\log 100} e^{-\pi{e^y}/2 - i e^y (y + x)} - 1 \,dy??$$

# %%
def cf_to_cdf(cf, x):
    def f(z):
        return np.imag(cf(z) * np.exp(-1j*x*z) - cf(0)) / z
    r1 = scipy.integrate.quad(f, -100, 0)
    r2 = scipy.integrate.quad(f, 0, 100)
    r = r1[0] + r2[0]
    e = r1[1] + r2[1]
    #print("estimated error is", e/np.pi/2)
    r = r / np.pi / 2
    return 0.5 - r

# %%
class curlyj:
    @staticmethod
    def cf(theta):
        if theta == 0:
            return 1
        return np.exp(-1j*theta*np.log(-1j*theta))

    @staticmethod
    def cdf(xx):
        return cf_to_cdf(curlyj.cf, xx)

# %%
for many in [10, 100, 1000, 10000, 100000, 1000000]:
    p.figure(figsize=(16, 6))

    x = np.linspace(-10, 20, 200)
    y = [curlyj.cdf(_) for _ in x]
    p.title("Plot of the cumulative distribution function for $N = %d$" % many)
    p.plot(x, y)

    cdf(samples_for_n[many])
    p.xlabel("$(S_N - N\,\log\,N) / N$")
    p.ylabel("cumulative probability")
    p.xlim([-20, 20])
    p.show()
# Out:
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   r2 = scipy.integrate.quad(f, 0, 100)

# %%
curlyj.cdf(10000)
# Out:
# <ipython-input-271-7298ffd856fe>:4: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   r1 = scipy.integrate.quad(f, -100, 0)
# <ipython-input-271-7298ffd856fe>:5: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   r2 = scipy.integrate.quad(f, 0, 100)
# 1.3824497655955452

# %% [markdown]
# ### The distribution of the walk after $N$ samples

# %%
def draw():
    return int(np.floor(1/np.random.random()))

def walk(L, q, start):
    yield start
    while True:
        if np.random.random() < q:
            start -= 1
        else:
            if np.random.random() < 0.5:
                zz = draw()
                start += max(zz - start, 0)
                # whee
            else:
                start += draw()
        if start == 0:
            return start
        if start > L:
            start = L
        yield start

def conjectured_critical_q(L, shift=1):
    return 1 - 1/(1 + shift * 0.5 * np.log(L))

# %%
def _():
    x = np.linspace(10, 1000, 400)
    y = conjectured_critical_q(x)
    p.title("The conjectured critical value of $q$ as $L$ varies.")
    p.xlabel("$L$")
    p.ylabel("$q = 1 - 1/(1 + \\frac{1}{2} \\log\, L)$")
    p.ylim([0, 1])
    p.plot(x, y)
_()

# %%
longwalk = list(walk(1000, 0.7, 1000))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1aff39352e5d> in <module>
# ----> 1 longwalk = list(walk(1000, 0.7, 1000))
#
# <ipython-input-15-4b9e15afd41c> in walk(L, q, start)
#      13                 # whee
#      14             else:
# ---> 15                 start += draw()
#      16         if start == 0:
#      17             return start
#
# <ipython-input-15-4b9e15afd41c> in draw()
#       1 def draw():
# ----> 2     return int(np.floor(1/np.random.random()))
#       3
#       4 def walk(L, q, start):
#       5     yield start
#
# KeyboardInterrupt:

# %%
p.figure(figsize=(30, 6))
p.plot(longwalk[-6000:])
p.show()

# %%
bblong = list(bbwalk(1000, 0.498, 1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7fd74a0916d1> in <module>
# ----> 1 bblong = list(bbwalk(1000, 0.498, 1000))
#
# NameError: name 'bbwalk' is not defined
